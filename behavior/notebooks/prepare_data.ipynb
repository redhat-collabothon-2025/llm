# %%
# !pip install -q instructlab datasets transformers

import json
from scripts.generate_training import generate_training_dataset

generate_training_dataset('datasets/fake_bank_logs.json', 'datasets/training_dataset.json')

with open('datasets/training_dataset.json', 'r', encoding='utf-8') as f:
    training_data = json.load(f)

print(f"Number of training instructions: {len(training_data)}")
print("Sample instruction:")
print(training_data[0])
