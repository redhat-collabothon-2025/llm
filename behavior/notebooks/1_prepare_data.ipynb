# %% [markdown]
# # Data Preparation for Bank Log Anomaly Detection

# %%
# !pip install --upgrade pip
# !pip install pandas numpy scikit-learn

# %%
import sys
sys.path.append('..')

from scripts.prepare_data import prepare_training_data

train_df, val_df, test_df = prepare_training_data(
    '../datasets/employee_activity_logs.json',
    'data'
)

# %%
import pandas as pd

train = pd.read_csv('data/train.csv')
print("Training data shape:", train.shape)
print("\nFirst few rows:")
print(train.head())

print("\nAnomaly distribution:")
print(train['anomaly'].value_counts())

# %%
print("\nData Statistics:")
print(train.describe())
