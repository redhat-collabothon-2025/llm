# %%
import instructlab as ilab

model_name = "ibm/granite-7b-instruct"
data_path = 'datasets/training_dataset.json'
output_dir = 'models/finetuned_granite'

ilab.train(
    model=model_name,
    data_dir=data_path,
    output_dir=output_dir,
    num_epochs=10,
    batch_size=4,
    learning_rate=1e-4,
    hardware_accelerators='cuda'
)
