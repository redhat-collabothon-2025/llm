# %%
import sys
sys.path.append('../scripts')
from generate_logs import generate_dataset
import json

print("Generating synthetic security logs...")
logs = generate_dataset()

with open('../outputs/synthetic_logs.json', 'w') as f:
    json.dump(logs, f, indent=2)

print(f"✅ Generated {len(logs)} synthetic logs")

print("\nExample log:")
print(json.dumps(logs[0], indent=2))
